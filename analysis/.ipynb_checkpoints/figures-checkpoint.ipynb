# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("../data/demeaned.csv")
df = data.groupby(["id", "ispolice", "sellerfeedbackscore", "bidcount", "apple", "amazon"])["bids"].apply(lambda x: x.values).reset_index()

# %%
plt.style.use('seaborn-pastel')
plt.rcParams['figure.figsize'] = (8,5)
plt.rcParams['figure.dpi'] = 500
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'
plt.rcParams['axes.titlepad'] = 10
plt.rcParams['axes.titleweight'] = 1000
plt.rcParams['axes.labelpad'] = 5
plt.rcParams['font.family'] = 'serif'
plt.rcParams['axes.facecolor'] = 'white'

# %%
fig, ax = plt.subplots()

plt.hist(data.bids, bins=50)

plt.xlim(-0.5,7)
plt.xlabel("Bidder valuation")
plt.ylabel("Frequency")

plt.tight_layout()
fig.savefig("bids.png", dpi=fig.dpi, bbox_inches="tight")
plt.close(fig)

# %%
data
# Out:
#                 id  apple  samsung  amazon  others                model  \
# 0     115546954283      1        0       0       0           ipad pro 5
# 1     115546954283      1        0       0       0           ipad pro 5
# 2     115546954283      1        0       0       0           ipad pro 5
# 3     115546954283      1        0       0       0           ipad pro 5
# 4     115546954283      1        0       0       0           ipad pro 5
# ...            ...    ...      ...     ...     ...                  ...
# 5821  404155888980      0        1       0       0        galaxy tab s2
# 5822  404159194902      0        0       1       0  kindle paperwhite 7
# 5823  404159194902      0        0       1       0  kindle paperwhite 7
# 5824  404159194902      0        0       1       0  kindle paperwhite 7
# 5825  404159194902      0        0       1       0  kindle paperwhite 7
#
#       screensize  storage  isnight  returnsaccepted  ...  selleryearpercent  \
# 0           12.9      128        0                0  ...                100
# 1           12.9      128        0                0  ...                100
# 2           12.9      128        0                0  ...                100
# 3           12.9      128        0                0  ...                100
# 4           12.9      128        0                0  ...                100
# ...          ...      ...      ...              ...  ...                ...
# 5821         9.7       32        1                0  ...                100
# 5822         6.0        4        0                0  ...                100
# 5823         6.0        4        0                0  ...                100
# 5824         6.0        4        0                0  ...                100
# 5825         6.0        4        0                0  ...                100
#
#       isused  isbroken  deliveryspeed  startingprice issold  bidcount  \
# 0          0         0            1.0       2.052935      1         7
# 1          0         0            1.0       2.052935      1         7
# 2          0         0            1.0       2.052935      1         7
# 3          0         0            1.0       2.052935      1         7
# 4          0         0            1.0       2.052935      1         7
# ...      ...       ...            ...            ...    ...       ...
# 5821       1         0            0.0       0.543364      1         6
# 5822       1         0            0.0       1.981248      1         4
# 5823       1         0            0.0       1.981248      1         4
# 5824       1         0            0.0       1.981248      1         4
# 5825       1         0            0.0       1.981248      1         4
#
#       ruletriggered  nobid  residual
# 0                 0      1  0.658682
# 1                 0      2  0.618194
# 2                 0      3  0.390090
# 3                 0      4  0.326355
# 4                 0      5  0.255911
# ...             ...    ...       ...
# 5821              0      6 -0.573409
# 5822              1      1  1.148566
# 5823              1      2  1.091387
# 5824              1      3  0.977029
# 5825              1      4  0.862671
#
# [5826 rows x 29 columns]
