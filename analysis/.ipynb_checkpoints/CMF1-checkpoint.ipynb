# %% [markdown]
# Here we estimate the following conditional median function:
# $$
# \text{med}[valuation_i|ispolice_i]=\alpha+\beta_1 ispolice_i,
# $$
# using the entire sample where the number of bids received is strictly between 3 and 12.

# %%
import sys
import pandas as pd
 
sys.path.append('../')

from functions import *

data = pd.read_csv("../data/demeaned.csv")
df = data.groupby(["id", "ispolice", "sellerfeedbackscore", "bidcount", "apple", "amazon", "increment_residual"])["residual"].apply(lambda x: x.values).reset_index()

# %%
valid_bids = list(df[df.ispolice == 1].bidcount.value_counts().index)
include = df[df.bidcount.isin(valid_bids) & (df.bidcount > 1)]

bids = list(include.residual)
covariates = [[cov] for cov in list(include.ispolice)]
incremented = list(include.increment_residual)

# %%
median_upper, median_lower = estimate_median(bids, covariates, incremented, (-4,6))
# Out:
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00012811900000020415s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 46.710961252000004s

# %%
def loss_function(c):
    a, b = c
    cef = lambda cov: a+b*cov[0]
    return get_loss_function(covariates, median_upper, median_lower, cef)

point, interval = get_estimates(loss_function, 2)

print(point)
print(interval)
# Out:
# [-0.41785203  0.05223783]
# [-0.46320207967509813, -0.3766773312071483, -0.1474729837813158, 0.3891828954781248]

# %%
cef = lambda c, cov: c[0]+c[1]*cov[0]
n_cov = 2

results = bootstrap(include, bids, covariates, incremented, [n_cov], [cef], 500)
# Out:
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00014733000000433094s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.784287351s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00013742100000513346s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 37.371836865999995s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.423700001320867e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 37.53363708600003s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.0001290329999505957s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.01404258699995s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010453400000187685s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 40.36382523000003s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00021565599996620222s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 47.11161292999998s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.0001323339999999007s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.241773179999996s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.027999999489111e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.18533574100002s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00011369800006377773s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 36.21092678600007s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.0001281229999676725s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 40.021409191999965s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00012744699995437259s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.12401606200001s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00013390199990226392s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 44.89879843199992s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010047599994322809s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.14316006599984s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.994699985327316e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 45.00380638499996s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010209700008090294s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 41.20952497600001s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010780799993881374s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.37157304399989s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.775899980013492e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 40.294078463999995s
# An error occurred while calculating intervals on iteration 17
# singular matrix
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00020755499986080395s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 41.95740996299992s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010872000007111637s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.80768704399998s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010070600001199637s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 40.4944045000002s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.750699996402545e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 43.190794893999964s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.69269999586686e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.02615260499988s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010161099999095313s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 38.50028519500006s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010308899982192088s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 40.36010098399993s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.63210000008985e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.327164997999944s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010357299970564782s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.076597814999786s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010088999988511205s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.567683575000046s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010408200023448444s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.91363581700034s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010861100008696667s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 41.21511968699997s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.0001419139998688479s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.137786082000275s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010137999970538658s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 41.44210491400008s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.371400028612697e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.85185795999996s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.767399978954927e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.34661453799981s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.53750000007858e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.78362059600022s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.852399989540572e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 49.42977182899995s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.724199981064885e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 46.23619557799975s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00015155599976424128s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.03808234400003s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010255899996991502s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 40.35876802899975s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.686099974715034e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 45.117365124000116s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010365500020270701s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 43.52597648100027s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.755200017025345e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 41.57644201400035s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.909800019158865e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 46.39102356300009s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.0012827840000682045s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.74814435999997s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.790700005396502e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 46.781262943s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.0002251189998787595s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 47.05507560800015s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010233300008621882s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 39.79833757200004s
# /Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py:574: RuntimeWarning: Degrees of freedom <= 0 for slice
#   self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
# /Users/liumukun/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2680: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# /Users/liumukun/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py:2680: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# An error occurred while calculating intervals on iteration 47
# array must not contain infs or NaNs
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.000171507999766618s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 42.568603489s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.798899964152952e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 43.136781764999796s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.936900005413918e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 47.021117141000104s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.922899971570587e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 43.80556844699959s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.714600037113996e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 46.98490094800036s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.588099965185393e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 44.62688605800031s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.636800041334936e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 44.76326659700044s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010202000066783512s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 43.746710305000306s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.665499965194613e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 44.70075680699938s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010040800043498166s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 44.262884931999906s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00018328500027564587s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 43.14681142900008s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 9.873199996945914e-05s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 44.791353382000125s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.00010121900049853139s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 46.202030424999975s
# calculating values for covariate: [0] (1/2)
# total time elapsed: 0.0001530740000816877s
# calculating values for covariate: [1] (2/2)
# total time elapsed: 46.982549669000036s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-a84dac2d3426> in <module>
#       2 n_cov = 2
#       3
# ----> 4 results = bootstrap(include, bids, covariates, incremented, [n_cov], [cef], 500)
#
# ~/Desktop/projects/eme/analysis/functions/bootstrap.py in bootstrap(full_df, bids, covariates, incremented, n_covs, cefs, repetition)
#      81         try:
#      82
# ---> 83             median_upper, median_lower = estimate_median(_bids, _covariates, _incremented, (-4,6))
#      84
#      85             results = []
#
# ~/Desktop/projects/eme/analysis/functions/median.py in estimate_median(bids, covariates, incremented, _range)
#     130         print(f"calculating values for covariate: {covariate} ({idx+1}/{len(unique_covariates)})")
#     131         print(f"total time elapsed: {time.perf_counter()-start}s")
# --> 132         lower, upper = get_estimated_medians(pdfs, pdfs_delta, covariate, _range)
#     133         median_upper[f"{covariate}"] = upper
#     134         median_lower[f"{covariate}"] = lower
#
# ~/Desktop/projects/eme/analysis/functions/median.py in get_estimated_medians(pdfs, pdfs_delta, x_val, interpolation_range)
#      94
#      95
# ---> 96     upper_bound_median = optimize.bisect(lambda x: smooth_upper_bound_cdf(x,-1)-0.5, x0, x1, xtol=0.001)
#      97     lower_bound_median = optimize.bisect(lambda x: smooth_lower_bound_cdf(x,1)-0.5, x0, x1, xtol=0.001)
#      98
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/zeros.py in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     551     if rtol < _rtol:
#     552         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 553     r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     554     return results_c(full_output, r)
#     555
#
# ~/Desktop/projects/eme/analysis/functions/median.py in <lambda>(x)
#      94
#      95
# ---> 96     upper_bound_median = optimize.bisect(lambda x: smooth_upper_bound_cdf(x,-1)-0.5, x0, x1, xtol=0.001)
#      97     lower_bound_median = optimize.bisect(lambda x: smooth_lower_bound_cdf(x,1)-0.5, x0, x1, xtol=0.001)
#      98
#
# ~/Desktop/projects/eme/analysis/functions/median.py in smooth_upper_bound_cdf(x, p)
#      68         for cdf in parent_cdf_estimates_upper:
#      69             try:
# ---> 70                 all_values.append(cdf(x))
#      71             except Exception as e:
#      72                 # print(f"error occurred for one cdf while calculating upper bound for {x}")
#
# ~/Desktop/projects/eme/analysis/functions/median.py in <lambda>(x, i, conditional_cdf_i_N)
#      49             conditional_cdf_i_N = lambda y, conditional_pdf_i_N=conditional_pdf_i_N: integrate.quad(conditional_pdf_i_N, a=x0, b=y)[0]
#      50
# ---> 51             parent_conditional_cdf_from_i_N = lambda x, i=i, conditional_cdf_i_N=conditional_cdf_i_N: cdf(x, conditional_cdf_i_N, i+1, N_BIDS)/cdf(x1, conditional_cdf_i_N, i+1, N_BIDS)
#      52
#      53             parent_cdf_estimates_upper.append(parent_conditional_cdf_from_i_N)
#
# ~/Desktop/projects/eme/analysis/functions/cdf_mapping.py in cdf(x, order_statistic_cdf, i, n)
#      23     """
#      24
# ---> 25     f_x = min(order_statistic_cdf(x),1)
#      26     nearest = round(round(f_x / 0.0002) * 0.0002, -int(math.floor(math.log10(0.0002))))
#      27
#
# ~/Desktop/projects/eme/analysis/functions/median.py in <lambda>(y, conditional_pdf_i_N)
#      47
#      48             conditional_pdf_i_N = conditional_pdf_N[i]
# ---> 49             conditional_cdf_i_N = lambda y, conditional_pdf_i_N=conditional_pdf_i_N: integrate.quad(conditional_pdf_i_N, a=x0, b=y)[0]
#      50
#      51             parent_conditional_cdf_from_i_N = lambda x, i=i, conditional_cdf_i_N=conditional_cdf_i_N: cdf(x, conditional_cdf_i_N, i+1, N_BIDS)/cdf(x1, conditional_cdf_i_N, i+1, N_BIDS)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     339
#     340     if weight is None:
# --> 341         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     342                        points)
#     343     else:
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     451     if points is None:
#     452         if infbounds == 0:
# --> 453             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     454         else:
#     455             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#
# ~/Desktop/projects/eme/analysis/functions/median.py in <lambda>(y, pdf)
#      41         weight = 1
#      42
# ---> 43         conditional_pdf_N = [lambda y, pdf=pdf: pdf(y)/weight for pdf in conditional_pdfs[key]]
#      44
#      45
#
# ~/Desktop/projects/eme/analysis/functions/get_pdfs.py in <lambda>(_y)
#      47     conditional_kde = lambda _x, _y: joint_kde.pdf(_x + [_y]) / marginal_kde.pdf(_x)
#      48
# ---> 49     return lambda _x: (lambda _y: conditional_kde(_x, _y))
#      50     # return lambda _x: (lambda _y: 2*conditional_kde(_x, _y))
#      51
#
# ~/Desktop/projects/eme/analysis/functions/get_pdfs.py in <lambda>(_x, _y)
#      45     marginal_kde = stats.gaussian_kde(np.transpose(np.array(x)))
#      46
# ---> 47     conditional_kde = lambda _x, _y: joint_kde.pdf(_x + [_y]) / marginal_kde.pdf(_x)
#      48
#      49     return lambda _x: (lambda _y: conditional_kde(_x, _y))
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in pdf(self, x)
#     591
#     592         """
# --> 593         return self.evaluate(x)
#     594
#     595     def logpdf(self, x):
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in evaluate(self, points)
#     261                 result[i] = sum(exp(-energy)*self.weights, axis=0)
#     262
# --> 263         result = result / self._norm_factor
#     264
#     265         return result
#
# KeyboardInterrupt:

# %%
a_lower, a_upper, b_lower, b_upper = [[a[0][i] for a in results] for i in range(4)]
print(f"a cf: [{np.percentile(a_lower, 5)}, {np.percentile(a_upper, 95)}]")
print(f"b cf: [{np.percentile(b_lower, 5)}, {np.percentile(b_upper, 95)}]")
