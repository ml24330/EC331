# %%
import pandas as pd
import numpy as np
from scipy import optimize
from main import estimate_median, get_loss_function, transform_covariates

data = pd.read_csv("../../data/demeaned.csv")
df = data.groupby(["id", "ispolice", "sellerfeedbackscore", "bidcount", "apple", "amazon"])["bids"].apply(lambda x: x.values).reset_index()

# %%
from scipy import stats

def simulate(row, c):
    b0, b1, b2 = c
    ispolice = row.ispolice
    feedbackscore = np.log(row.sellerfeedbackscore+1)
    bidcount = row.bidcount
    median = b0+ispolice*b1+feedbackscore*b2
    bids = stats.norm.rvs(loc=median, scale=0.5, size=bidcount)
    
    return sorted(bids)

# %%
deviations = []

# %%
for i in range(10):
    print(f"Starting round {i+1}/10...")
    
    b0 = np.random.random()
    # b0 = 0

    # b1 = np.random.random()
    b1 = 0

    b2 = np.random.random()/2
    # b2 = 0


    df.bids = df.apply(lambda row: simulate(row, (b0,b1,b2)), axis=1)
    df.bids = df.bids.apply(lambda bids: [bid-min([bid[0] for bid in list(df.bids)]) for bid in bids])

    include = df[(df.bidcount > 3) & (df.bidcount < 12)]

    bids = list(include.bids)
    logged_feedback = np.log(include.sellerfeedbackscore+1)
    covariates = [[cov] for cov in list(logged_feedback)]

    covariates = [[cov] for cov in transform_covariates([cov[0] for cov in covariates],100)]
    
    
    median_upper, median_lower = estimate_median(bids, covariates, (0,10))
    
    def loss_function(c):
        a, b = c
        cef = lambda cov: a+b*cov[0]
        return get_loss_function(covariates, median_upper, median_lower, cef)
    
    b_hat = optimize.brute(loss_function, ranges=[(0,2), (-1,1)])
    
    deviation = loss_function([b0, b2])-loss_function(b_hat)
    
    deviations.append(deviation)
    
    print(f"difference is {deviation}")
# Out:
# Starting round 1/10...
# calculating values for covariate: [6.10671937212663] (1/94)
# total time elapsed: 0.00010152499999982467s
# calculating values for covariate: [5.664566951481543] (2/94)
# total time elapsed: 17.258119290000003s
# calculating values for covariate: [4.7432581672086735] (3/94)
# total time elapsed: 34.035786443999996s
# calculating values for covariate: [6.130073340709003] (4/94)
# total time elapsed: 48.961808257s
# calculating values for covariate: [5.902142456688845] (5/94)
# total time elapsed: 65.572621117s
# calculating values for covariate: [5.8185067592433874] (6/94)
# total time elapsed: 82.991442861s
# calculating values for covariate: [9.546066487834448] (7/94)
# total time elapsed: 97.92058191299999s
# calculating values for covariate: [5.619738966403259] (8/94)
# total time elapsed: 116.645794799s
# calculating values for covariate: [4.32625977490886] (9/94)
# total time elapsed: 135.951346215s
# calculating values for covariate: [9.955277308666151] (10/94)
# total time elapsed: 153.061826791s
# calculating values for covariate: [13.165418051265528] (11/94)
# total time elapsed: 168.387617695s
# calculating values for covariate: [5.25221821313404] (12/94)
# total time elapsed: 183.668799704s
# calculating values for covariate: [5.382785465251274] (13/94)
# total time elapsed: 202.604510583s
# calculating values for covariate: [11.68206575054986] (14/94)
# total time elapsed: 219.698603704s
# calculating values for covariate: [6.264731630328883] (15/94)
# total time elapsed: 236.008960234s
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3418, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-8430147060ea>", line 26, in <module>
#     median_upper, median_lower = estimate_median(bids, covariates, (0,10))
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 451, in estimate_median
#     lower, upper = get_estimated_medians(pdfs, pdfs_delta, covariate, (0,9))
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 349, in get_estimated_medians
#     upper_bound_median = optimize.bisect(lambda x: smooth_upper_bound_cdf(x,0)-0.5, x0, x1, xtol=0.001)
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/optimize/zeros.py", line 553, in bisect
#     r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 349, in <lambda>
#     upper_bound_median = optimize.bisect(lambda x: smooth_upper_bound_cdf(x,0)-0.5, x0, x1, xtol=0.001)
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 338, in smooth_upper_bound_cdf
#     all_values = [cdf(x) for cdf in parent_cdf_estimates_upper]
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 338, in <listcomp>
#     all_values = [cdf(x) for cdf in parent_cdf_estimates_upper]
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 322, in <lambda>
#     parent_conditional_cdf_from_i_N = lambda x: parent_conditional_cdf_from_i_N_(x)/parent_conditional_cdf_from_i_N_(x1)
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 88, in <lambda>
#     return lambda x: cdf(x, order_statistic_cdf, i, n)
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 46, in cdf
#     f_x = min(order_statistic_cdf(x),1)
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 319, in <lambda>
#     conditional_cdf_i_N = lambda y, conditional_pdf_i_N=conditional_pdf_i_N: integrate.quad(conditional_pdf_i_N, a=0, b=y)[0]
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py", line 341, in quad
#     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py", line 453, in _quad
#     return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 313, in <lambda>
#     conditional_pdf_N = [lambda y, pdf=pdf: pdf(y)/weight for pdf in conditional_pdfs[key]]
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 144, in <lambda>
#     return lambda _x: (lambda _y: 2*conditional_kde(_x, _y))
#   File "/Users/liumukun/Desktop/projects/eme/analysis/estimation_cmf/main.py", line 142, in <lambda>
#     conditional_kde = lambda _x, _y: joint_kde.pdf(_x + [_y]) / marginal_kde.pdf(_x)
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py", line 593, in pdf
#     return self.evaluate(x)
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py", line 246, in evaluate
#     whitening = linalg.cholesky(self.inv_cov)
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/linalg/decomp_cholesky.py", line 90, in cholesky
#     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/linalg/decomp_cholesky.py", line 37, in _cholesky
#     c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2045, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1170, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/liumukun/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/liumukun/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/liumukun/anaconda3/lib/python3.8/inspect.py", line 1461, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/liumukun/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/liumukun/anaconda3/lib/python3.8/inspect.py", line 754, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "/Users/liumukun/anaconda3/lib/python3.8/posixpath.py", line 391, in realpath
#     path, ok = _joinrealpath(filename[:0], filename, {})
#   File "/Users/liumukun/anaconda3/lib/python3.8/posixpath.py", line 425, in _joinrealpath
#     if not islink(newpath):
#   File "/Users/liumukun/anaconda3/lib/python3.8/posixpath.py", line 167, in islink
#     st = os.lstat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-4-8430147060ea> in <module>
#      25
# ---> 26     median_upper, median_lower = estimate_median(bids, covariates, (0,10))
#      27
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in estimate_median(bids, covariates, _range)
#     450         print(f"total time elapsed: {time.perf_counter()-start}s")
# --> 451         lower, upper = get_estimated_medians(pdfs, pdfs_delta, covariate, (0,9))
#     452         median_upper[f"{covariate}"] = upper
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in get_estimated_medians(pdfs, pdfs_delta, x_val, interpolation_range)
#     348
# --> 349     upper_bound_median = optimize.bisect(lambda x: smooth_upper_bound_cdf(x,0)-0.5, x0, x1, xtol=0.001)
#     350     lower_bound_median = optimize.bisect(lambda x: smooth_lower_bound_cdf(x,0)-0.5, x0, x1, xtol=0.001)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/optimize/zeros.py in bisect(f, a, b, args, xtol, rtol, maxiter, full_output, disp)
#     552         raise ValueError("rtol too small (%g < %g)" % (rtol, _rtol))
# --> 553     r = _zeros._bisect(f, a, b, xtol, rtol, maxiter, args, full_output, disp)
#     554     return results_c(full_output, r)
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in <lambda>(x)
#     348
# --> 349     upper_bound_median = optimize.bisect(lambda x: smooth_upper_bound_cdf(x,0)-0.5, x0, x1, xtol=0.001)
#     350     lower_bound_median = optimize.bisect(lambda x: smooth_lower_bound_cdf(x,0)-0.5, x0, x1, xtol=0.001)
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in smooth_upper_bound_cdf(x, p)
#     337     def smooth_upper_bound_cdf(x, p):
# --> 338         all_values = [cdf(x) for cdf in parent_cdf_estimates_upper]
#     339         ans = sum([g*np.exp(g*p) for g in all_values])/sum([np.exp(g*p) for g in all_values])
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in <listcomp>(.0)
#     337     def smooth_upper_bound_cdf(x, p):
# --> 338         all_values = [cdf(x) for cdf in parent_cdf_estimates_upper]
#     339         ans = sum([g*np.exp(g*p) for g in all_values])/sum([np.exp(g*p) for g in all_values])
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in <lambda>(x)
#     321             parent_conditional_cdf_from_i_N_ = get_cdf(conditional_cdf_i_N, i+1, N_BIDS)
# --> 322             parent_conditional_cdf_from_i_N = lambda x: parent_conditional_cdf_from_i_N_(x)/parent_conditional_cdf_from_i_N_(x1)
#     323
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in <lambda>(x)
#      87     """
# ---> 88     return lambda x: cdf(x, order_statistic_cdf, i, n)
#      89
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in cdf(x, order_statistic_cdf, i, n)
#      45     """
# ---> 46     f_x = min(order_statistic_cdf(x),1)
#      47     nearest = round(round(f_x / 0.0002) * 0.0002, -int(math.floor(math.log10(0.0002))))
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in <lambda>(y, conditional_pdf_i_N)
#     318             conditional_pdf_i_N = conditional_pdf_N[i]
# --> 319             conditional_cdf_i_N = lambda y, conditional_pdf_i_N=conditional_pdf_i_N: integrate.quad(conditional_pdf_i_N, a=0, b=y)[0]
#     320
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     340     if weight is None:
# --> 341         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     342                        points)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/integrate/quadpack.py in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     452         if infbounds == 0:
# --> 453             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     454         else:
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in <lambda>(y, pdf)
#     312
# --> 313         conditional_pdf_N = [lambda y, pdf=pdf: pdf(y)/weight for pdf in conditional_pdfs[key]]
#     314
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in <lambda>(_y)
#     143
# --> 144     return lambda _x: (lambda _y: 2*conditional_kde(_x, _y))
#     145
#
# ~/Desktop/projects/eme/analysis/estimation_cmf/main.py in <lambda>(_x, _y)
#     141
# --> 142     conditional_kde = lambda _x, _y: joint_kde.pdf(_x + [_y]) / marginal_kde.pdf(_x)
#     143
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in pdf(self, x)
#     592         """
# --> 593         return self.evaluate(x)
#     594
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/stats/kde.py in evaluate(self, points)
#     245
# --> 246         whitening = linalg.cholesky(self.inv_cov)
#     247         scaled_dataset = dot(whitening, self.dataset)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/linalg/decomp_cholesky.py in cholesky(a, lower, overwrite_a, check_finite)
#      89     """
# ---> 90     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=True,
#      91                          check_finite=check_finite)
#
# ~/anaconda3/lib/python3.8/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      36     potrf, = get_lapack_funcs(('potrf',), (a1,))
# ---> 37     c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      38     if info > 0:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         # in the engines. This should return a list of strings.
# -> 2045                         stb = value._render_traceback_()
#    2046                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                         stb = value._render_traceback_()
#    2046                     except Exception:
# -> 2047                         stb = self.InteractiveTB.structured_traceback(etype,
#    2048                                             value, tb, tb_offset=tb_offset)
#    2049
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434         else:
#    1435             self.tb = tb
# -> 1436         return FormattedTB.structured_traceback(
#    1437             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1438
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334         if mode in self.verbose_modes:
#    1335             # Verbose modes need a full traceback
# -> 1336             return VerboseTB.structured_traceback(
#    1337                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1338             )
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191         """Return a nice text document describing the traceback."""
#    1192
# -> 1193         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1194                                                                tb_offset)
#    1195
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1149
#    1150
# -> 1151         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1152
#    1153         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
