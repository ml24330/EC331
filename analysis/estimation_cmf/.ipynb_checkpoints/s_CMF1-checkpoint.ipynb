# %% [markdown]
# Here we estimate the following conditional median function:
# $$
# \text{med}[valuation_i|ispolice_i]=\alpha+\beta_1 ispolice_i,
# $$
# using the entire sample where the number of bids received is strictly between 3 and 12.

# %%
import sys
import pandas as pd
import re
 
sys.path.append('../')

from functions import *

df = pd.read_csv("../../data/simulated.csv")

def comma(s):
    add_comma = lambda match: match.group(0).replace(" ", ", ")
    
    s = s.replace("\n", "")

    s = re.sub(r"([0-9\.]+\s)", add_comma, s)
    
    return eval(s)

df.residual = df.residual.apply(comma)

# %%
include = df

bids = list(include.residual)
covariates = [[cov] for cov in list(include.ispolice)]
incremented = list(include.increment_residual)

# %%
median_upper, median_lower = estimate_median(bids, covariates, incremented, (-4,6))
# Out:
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00016621800000038434s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 55.720596989s

# %%
def loss_function(c):
    a, b = c
    cef = lambda cov: a+b*cov[0]
    return get_loss_function(covariates, median_upper, median_lower, cef)

point, interval = get_estimates(loss_function, 2)

print(point)
print(interval)
# Out:
# [-0.41662598  0.30481999]
# [-0.4444366937410478, -0.38944623670311945, -0.027296833520747216, 0.3617695043962438]

# %%
cef = lambda c, cov: c[0]+c[1]*cov[0]
n_cov = 2

results = bootstrap(include, bids, covariates, incremented, [n_cov], [cef], 500)
# Out:
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0003481659999948761s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 61.068742335999985s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00042705100000262064s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 53.30691791800001s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00011241699996844545s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 53.31595846199997s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00011336400001482616s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 69.03106366399999s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0001646140000275409s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 73.98451663900005s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0001391170000033526s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 79.30364959500002s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00015897700006917148s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 75.55782925000005s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00010074499994061625s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 78.44486086400002s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00013351899997360306s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 80.304498663s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0014179620000049908s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 65.8321547569999s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00014384600012817828s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 69.38659203600014s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0001301770000736724s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 68.71012458500013s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00016007199997147836s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 65.83520707699995s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00014004700005898485s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 73.21185455599993s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00010485999996490136s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 85.80796091999991s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0004236650001985254s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 69.77008160700007s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00014065999994272715s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 74.13233222100007s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00014973799989093095s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 67.96874745600007s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00010440999994898448s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 79.57837804199971s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0001413479999428091s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 72.74926248200018s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0001894359998004802s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 73.53755846800004s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00012847400012105936s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 70.53803741399997s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0003317750001770037s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 79.07203161899997s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00019294300000183284s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 71.42707699399989s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00014149000026009162s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 69.81879497399996s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00011157000017192331s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 85.99344252400033s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00014581699997506803s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 86.94414898099967s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0005754050002906297s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 75.60011200600002s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 9.854700010691886e-05s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 76.83087591599997s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00013073900026938645s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 69.49927637699966s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00013194700022722827s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 73.548650791s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0001631599998290767s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 70.93264914200063s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00010851899969566148s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 73.30557205100013s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.0002931240005636937s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 56.81804463300068s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00011124799948447617s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 54.8276558259995s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00011278900001343573s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 52.62151213099969s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00011144200016133254s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 55.536692557000606s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00011116300083813258s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 57.43271331900087s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00011171000005560927s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: 54.58311624900034s
# calculating values for covariate: [0.0] (1/2)
# total time elapsed: 0.00019070000053034164s
# calculating values for covariate: [1.0] (2/2)
# total time elapsed: