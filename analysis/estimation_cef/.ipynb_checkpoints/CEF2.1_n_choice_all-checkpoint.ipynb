# %% [markdown]
# Here we estimate the following conditional expectation function:
# $$
# \mathbb{E}[valuation_i|log\_sellerfeedbackscore_i]=\alpha+\beta_1 log\_sellerfeedbackscore_i,
# $$
# using the entire sample without considering the number of bids received.

# %%
import pandas as pd
import numpy as np
from scipy import optimize
from main import estimate_median, get_loss_function, transform_covariates

data = pd.read_csv("../../data/demeaned.csv")
df = data.groupby(["id", "ispolice", "sellerfeedbackscore", "bidcount", "apple", "amazon"])["bids"].apply(lambda x: x.values).reset_index()

# %%
compatible_bids = list(df[df.ispolice == 1].bidcount.value_counts().index)
include = df[df.bidcount.isin(compatible_bids)]

bids = list(include.bids)
logged_feedback = np.log(include.sellerfeedbackscore+1)
covariates = [[cov] for cov in list(logged_feedback)]

covariates = [[cov] for cov in transform_covariates([cov[0] for cov in covariates],100)]

# %%
expected_upper, expected_lower = estimate_mean(bids, covariates, (0,9))
# Out:
# calculating values for covariate: [3.3524442662096194] (1/100)
# total time elapsed: 0.0003543439999997844s
# /Users/liumukun/anaconda3/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1695: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   return integrate.quad(self._mom_integ1, 0, 1, args=(m,)+args)[0]
# calculating values for covariate: [5.979787415449747] (2/100)
# total time elapsed: 261.879225673s
# calculating values for covariate: [2.533449658204007] (3/100)
# total time elapsed: 598.129949333s
# calculating values for covariate: [4.3320091121662205] (4/100)
# total time elapsed: 931.7472917990001s
# calculating values for covariate: [6.950685674976283] (5/100)
# total time elapsed: 1355.953608753s
# calculating values for covariate: [7.271272950468081] (6/100)
# total time elapsed: 1726.670555096s
# calculating values for covariate: [5.888120972371637] (7/100)
# total time elapsed: 2040.032028277s
# calculating values for covariate: [8.012520509835065] (8/100)
# total time elapsed: 2311.508472213s
# calculating values for covariate: [7.010766195476258] (9/100)
# total time elapsed: 2539.482146984s
# calculating values for covariate: [5.580993455214383] (10/100)
# total time elapsed: 2751.910664247s
# calculating values for covariate: [2.824449727261541] (11/100)
# total time elapsed: 2959.781669776s
# calculating values for covariate: [5.521842139625886] (12/100)
# total time elapsed: 3159.319071729s
# calculating values for covariate: [6.694515345972271] (13/100)
# total time elapsed: 3354.034839583s
# calculating values for covariate: [3.8277916524436253] (14/100)
# total time elapsed: 3549.278079848s
# calculating values for covariate: [6.509992393040078] (15/100)
# total time elapsed: 3764.546344122s
# calculating values for covariate: [3.492086285073702] (16/100)
# total time elapsed: 3990.585672951s
# calculating values for covariate: [8.190342801842357] (17/100)
# total time elapsed: 4200.756718607s
# calculating values for covariate: [5.481585222520285] (18/100)
# total time elapsed: 4412.727125169999s
# calculating values for covariate: [5.261364567330008] (19/100)
# total time elapsed: 4638.911584869s
# calculating values for covariate: [6.486513019671136] (20/100)
# total time elapsed: 4855.469293597999s
# calculating values for covariate: [9.487024917706549] (21/100)
# total time elapsed: 5072.405612684999s
# calculating values for covariate: [9.955277308666153] (22/100)
# total time elapsed: 5285.208619659s
# calculating values for covariate: [10.714726007498367] (23/100)
# total time elapsed: 5507.813009371999s
# calculating values for covariate: [6.252981466966596] (24/100)
# total time elapsed: 5716.679275189999s
# calculating values for covariate: [6.660344901031666] (25/100)
# total time elapsed: 5924.8443949719995s
# calculating values for covariate: [7.139713580370823] (26/100)
# total time elapsed: 6171.027586456999s
# calculating values for covariate: [4.978901938846929] (27/100)
# total time elapsed: 6382.147823482s
# calculating values for covariate: [7.482556959512772] (28/100)
# total time elapsed: 6591.994906434s
# calculating values for covariate: [9.69370293408745] (29/100)
# total time elapsed: 6788.731740996999s
# calculating values for covariate: [4.707890119869979] (30/100)
# total time elapsed: 6989.0514208019995s
# calculating values for covariate: [8.283085105665934] (31/100)
# total time elapsed: 7197.9499745349995s
# calculating values for covariate: [7.954475519512463] (32/100)
# total time elapsed: 7394.986362959s
# calculating values for covariate: [2.28815873655513] (33/100)
# total time elapsed: 7583.968982015999s
# calculating values for covariate: [6.775978638583625] (34/100)
# total time elapsed: 7806.538419445999s
# calculating values for covariate: [12.927696006587961] (35/100)
# total time elapsed: 8038.9962093369995s
# calculating values for covariate: [4.588530380982284] (36/100)
# total time elapsed: 8243.404473826s
# calculating values for covariate: [6.116139732806552] (37/100)
# total time elapsed: 8451.439321386s
# calculating values for covariate: [8.482173698698947] (38/100)
# total time elapsed: 8664.503619930001s
# calculating values for covariate: [4.865390032106561] (39/100)
# total time elapsed: 8879.901531927s
# calculating values for covariate: [6.739325217231219] (40/100)
# total time elapsed: 9098.244040739s
# calculating values for covariate: [6.382462599402439] (41/100)
# total time elapsed: 9315.058655499s
# calculating values for covariate: [6.329437001671614] (42/100)
# total time elapsed: 9531.258934598001s
# calculating values for covariate: [5.786362310653337] (43/100)
# total time elapsed: 9748.778068669s
# calculating values for covariate: [5.308710991538947] (44/100)
# total time elapsed: 9959.260262228001s
# calculating values for covariate: [7.5643505225246495] (45/100)
# total time elapsed: 10171.997794246001s
# calculating values for covariate: [5.66892376443991] (46/100)
# total time elapsed: 10384.275538976s
# calculating values for covariate: [6.149430350712189] (47/100)
# total time elapsed: 10600.156638287s
# calculating values for covariate: [8.89711766135026] (48/100)
# total time elapsed: 10819.160432822s
# calculating values for covariate: [4.206434182253519] (49/100)
# total time elapsed: 11029.066249787s
# calculating values for covariate: [9.436794237468936] (50/100)
# total time elapsed: 11242.532102196s
# calculating values for covariate: [5.620782532867282] (51/100)
# total time elapsed: 11456.645420914001s
# calculating values for covariate: [8.153212608875544] (52/100)
# total time elapsed: 11663.837211149s
# calculating values for covariate: [4.63829374083503] (53/100)
# total time elapsed: 11877.139511554s
# calculating values for covariate: [5.165054621323595] (54/100)
# total time elapsed: 12094.301724003s
# calculating values for covariate: [9.484552478583174] (55/100)
# total time elapsed: 12295.337501215s
# calculating values for covariate: [3.6427829616722454] (56/100)
# total time elapsed: 12507.505938687s
# calculating values for covariate: [5.3692759266075605] (57/100)
# total time elapsed: 12720.414969648s
# calculating values for covariate: [0.25993019270997947] (58/100)
# total time elapsed: 12943.565585289001s
# calculating values for covariate: [7.071841727763689] (59/100)
# total time elapsed: 13167.003141340001s
# calculating values for covariate: [3.2237784140123606] (60/100)
# total time elapsed: 13376.020651037s
# calculating values for covariate: [6.201247042837766] (61/100)
# total time elapsed: 13598.869914859s
# calculating values for covariate: [5.93276490629531] (62/100)
# total time elapsed: 13815.724926041s
# calculating values for covariate: [4.927135898745242] (63/100)
# total time elapsed: 14023.145889582s
# calculating values for covariate: [5.078001361280696] (64/100)
# total time elapsed: 14215.62384728s
# calculating values for covariate: [3.9595968567839526] (65/100)
# total time elapsed: 14415.555833737s
# calculating values for covariate: [6.548848250422037] (66/100)
# total time elapsed: 14656.870690256s
# calculating values for covariate: [10.006479679462197] (67/100)
# total time elapsed: 14891.233842184001s
# calculating values for covariate: [6.900064209655852] (68/100)
# total time elapsed: 15090.720010203s
# calculating values for covariate: [7.853349184091726] (69/100)
# total time elapsed: 15276.993577206s
# calculating values for covariate: [6.599439716505273] (70/100)
# total time elapsed: 15464.061758837s
# calculating values for covariate: [6.18073393366106] (71/100)
# total time elapsed: 15648.081548927s
# calculating values for covariate: [4.07496572905667] (72/100)
# total time elapsed: 15833.075855469s
# calculating values for covariate: [9.481255893085342] (73/100)
# total time elapsed: 16019.515447279s
# calculating values for covariate: [5.4235444455003545] (74/100)
# total time elapsed: 16206.488707721s
# calculating values for covariate: [5.743941437996736] (75/100)
# total time elapsed: 16392.045627153002s
# calculating values for covariate: [11.33844375855547] (76/100)
# total time elapsed: 16580.14305284s
# calculating values for covariate: [6.439596388697101] (77/100)
# total time elapsed: 16764.574337662s
# calculating values for covariate: [5.835066362946046] (78/100)
# total time elapsed: 16956.768977678s
# calculating values for covariate: [5.1997305895185315] (79/100)
# total time elapsed: 17146.256108751s
# calculating values for covariate: [4.424560699360533] (80/100)
# total time elapsed: 17333.97060206s
# calculating values for covariate: [10.75380590378735] (81/100)
# total time elapsed: 17523.941053092s
# calculating values for covariate: [7.407673760418058] (82/100)
# total time elapsed: 17711.775318599s
# calculating values for covariate: [7.205471171836157] (83/100)
# total time elapsed: 17898.411594195s
# calculating values for covariate: [1.2277304454369522] (84/100)
# total time elapsed: 18085.498270738s
# calculating values for covariate: [6.8388384000963995] (85/100)
# total time elapsed: 18276.866226263s
# calculating values for covariate: [8.069807973999874] (86/100)
# total time elapsed: 18464.479394241s
# calculating values for covariate: [6.617297006879771] (87/100)
# total time elapsed: 18652.983819182s
# calculating values for covariate: [2.119673090808945] (88/100)
# total time elapsed: 18838.281739951002s
# calculating values for covariate: [6.081863851886263] (89/100)
# total time elapsed: 19026.172972038s
# calculating values for covariate: [7.320708614691379] (90/100)
# total time elapsed: 19209.767776893s
# calculating values for covariate: [7.710150199345256] (91/100)
# total time elapsed: 19393.67400721s
# calculating values for covariate: [4.525454164522782] (92/100)
# total time elapsed: 19611.793688868s
# calculating values for covariate: [1.7619265553871364] (93/100)
# total time elapsed: 19827.966878244002s
# calculating values for covariate: [4.796521066437497] (94/100)
# total time elapsed: 20049.145227868s
# calculating values for covariate: [6.0414077151549455] (95/100)
# total time elapsed: 20255.114261257s

# %%
def loss_function(c):
    a, b = c
    cef = lambda cov: a+b*cov[0]
    return get_loss_function(covariates, expected_upper, expected_lower, cef)

b_hat = optimize.brute(loss_function, ranges=[(0,2), (-1,1)])
# interval_lower = optimize.newton(lambda a_l, b_l: loss_function(a_l, b_l)-loss_function(b_hat)-10, b_hat-0.1)
# interval_upper = optimize.newton(lambda b_l, b_u: loss_function(b_l, b_u)-loss_function(b_hat)-10, b_hat+0.1)

# %%
b_hat
# Out:
# array([0.58750368, 0.0382627 ])
