# %%
POLICE_CONS = [-0.3, -0.39, -0.15, -0.2]
NONPOLICE_CONS = [-0.99, -0.92, -0.895, -0.6]
POLICE_COEF = [-0.01, -0.012, 0.011, 0.01]
NONPOLICE_COEF = [0.02, 0.102, 0.106, 0.14]

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rcParams.update(matplotlib.rcParamsDefault)
plt.style.use('tableau-colorblind10')
plt.rcParams['figure.figsize'] = (5,3)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['text.color'] = 'black'
plt.rcParams['axes.labelcolor'] = 'black'
plt.rcParams['xtick.color'] = 'black'
plt.rcParams['ytick.color'] = 'black'
plt.rcParams['axes.titlepad'] = 5
plt.rcParams['axes.titlesize'] = 9
plt.rcParams['axes.labelsize'] = 8
plt.rcParams['axes.labelpad'] = 5
plt.rcParams['legend.fontsize'] = 7
plt.rcParams['font.family'] = 'serif'
plt.rcParams['axes.facecolor'] = 'white'

# %%
import numpy as np

func_conf_l = lambda r: - ( NONPOLICE_CONS[0] - POLICE_CONS[0] + NONPOLICE_COEF[0]*np.log(r+1) - POLICE_COEF[0]*np.log(r+1) )
func_l = lambda r: - ( NONPOLICE_CONS[1] - POLICE_CONS[1] + NONPOLICE_COEF[1]*np.log(r+1) - POLICE_COEF[1]*np.log(r+1) )
func_u = lambda r: - ( NONPOLICE_CONS[2] - POLICE_CONS[2] + NONPOLICE_COEF[2]*np.log(r+1) - POLICE_COEF[2]*np.log(r+1) )
func_conf_u = lambda r: - ( NONPOLICE_CONS[3] - POLICE_CONS[3] + NONPOLICE_COEF[3]*np.log(r+1) - POLICE_COEF[3]*np.log(r+1) )

values = np.linspace(0, 475, num=100)

plt.plot(values, [func_conf_l(v) for v in values], label="cl")
plt.plot(values, [func_l(v) for v in values], label="l")
plt.plot(values, [func_u(v) for v in values], label="u")
plt.plot(values, [func_conf_u(v) for v in values], label="cu")
plt.plot(vqalues, [0]*len(values), linestyle="dotted")

plt.legend()
